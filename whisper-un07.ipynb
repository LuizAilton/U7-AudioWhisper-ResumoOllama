# %% [markdown]
# # Explorando o whisper

# %%
# Exibe o caminho do interpretador Python que está sendo usado
# Útil para verificar se o notebook está utilizando o ambiente virtual correto
import sys
print(sys.executable)
# Out:
# C:\Users\LuizAilton\Desktop\TSI\28-TASI1\Aula7\Repositorio\venv\Scripts\python.exe

# %%
# Biblioteca de transcrição Whisper da OpenAI
#!pip install -U openai-whisper
import whisper

# %%
# Carrega o modelo Whisper
# Modelos possíveis: tiny, base, small, medium, large
model = whisper.load_model("large")

# %%
# Biblioteca para manipulação de arquivos
import os
mp3_path = 'ia-completa.mp3'

if not os.path.exists(mp3_path):
    print("Arquivo não encontrado!")
else:
    # Transcreve o áudio utilizando Whisper
    result = model.transcribe(mp3_path)

    # Obtém apenas o texto transcrito
    texto = result['text']

    # Exibe a transcrição completa
    print("Transcrição:")
    print(texto)
# Out:
# Transcrição:
#  o que é inteligência artificial generativa. Perfeito, acho que vale a pena explicar rapidamente o que é IA. IA é um software, mas diferente de um software convencional, que a gente tem um aplicativo no celular ou no computador, ele é um software que tem uma capacidade muito grande de entender padrões. Então eu consigo explicar para uma IA o que é um gato, o que é um tigre, o que é um cachorro. E depois que ela vê milhares de imagens de cachorro, de tigre, de gato, de casa, de igreja, de padre, de cadeira, ela consegue entender esses padrões. A partir desse momento eu consigo pedir para ela fazer uma imagem de um cachorro em cima de uma mesa, dentro de uma casa mal assombrada. E ela consegue gerar essas imagens porque ela entendeu esses padrões. Isso vale não só para gerar imagens, como vale para gerar textos estáticos, ou música, ou qualquer outra coisa. Essa é a parte da IA que a gente chama IA generativa.

# %%
# Biblioteca para comunicação com o Ollama
#!pip install ollama
import ollama

# %%
# Prompt enviado ao modelo LLM
# O modelo receberá a transcrição e produzirá um resumo
prompt = f"""
Você é um assistente especializado em resumir textos.

Leia a transcrição abaixo e gere:
- Um resumo curto

Transcrição:
{texto}
"""

# Envia o prompt ao modelo executado pelo Ollama
response = ollama.chat(
    model='llama3.2:3b',
    messages=[
        {
            'role': 'user',
            'content': prompt
        }
    ]
)

# Extrai a resposta do modelo
resumo = response['message']['content']

# Exibe o resumo final
print(resumo)
# Out:
# **Resumo:**
#
# A inteligência artificial (IA) generativa é um software capaz de entender padrões e gerar imagens, textos, música e outras formas de conteúdo com base nesses padrões. A IA pode ser treinada com milhares de exemplos, permitindo que ela aprenda a reconhecer padrões e criar novas formas de expressão. Isso abrange não apenas a geração de imagens, mas também textos estáticos, música e outras formas de conteúdo criativo.
